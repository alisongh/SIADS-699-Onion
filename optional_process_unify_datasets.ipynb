# %% [markdown]
# # <b>Data Processing: Unify All Pre-Processed Datasets</b>
# #### <font color = 'gray'>December 2022</font>

# %% [markdown]
# ###<b>Initial Set-Up & Mount Google Drive</b>

# %%
import pandas as pd
import plotly.express as px
import nltk
from nltk.corpus import stopwords

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
# # If running in Colab: connecting to Shared Google Drive
# # Run this cell and select your UMich Google account in the pop-up
# from google.colab import drive
# import sys
# drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# These paths will work if our project drive has been shared with you
GOLBECK_PATH = 'data\processed\satire_fake\full_golbeck_df'
MIHALCEA_PATH = 'data\processed\fake_real\Real-Fake-AllNewsData.xlsx'
YANG_TRAIN_PATH = 'data\processed\real_satire\updated_train_df.csv'
COMBINED_PATH = 'data\processed\combined_df.csv'

# Columns we want to keep across all datasets
KEEP_COLS = ['unique_id', 'label', 'source', 'text']
STOPS = stopwords.words("english")

# %% [markdown]
# ###<b>Import to DataFrame and Standardize Columns</b>

# %%
# Golbeck Fake-Satire
golbeck_df = pd.read_csv(GOLBECK_PATH, index_col=0)

# Add metadata and standardize
golbeck_df['source'] = 'Golbeck'
golbeck_df['unique_id'] = 'golbeck-' + golbeck_df['article_id'].astype(str)
golbeck_df['label'] = golbeck_df['label'].str.lower()
golbeck_df.rename({'text': 'article_only'}, axis=1, inplace=True)
golbeck_df.drop('article_id', axis=1, inplace=True)
golbeck_df['text'] = golbeck_df['title'].astype(str) + '\n' + golbeck_df['article_only'].astype(str)
golbeck_df.sample(5)
# Out:
#                                                  title  \
# 408         CANCER ENDORSES REPUBLICAN HEALTHCARE PLAN
# 372    New Comprehensive Investigation Involving Trump
# 371  U.S. FISH & WILDLIFE SERIOUSLY CONSIDERING ABU...
# 247  Iraq War Veteran Dies Trying to Protect Buffet...
# 271  Ted Cruz Still Leads Polls for Most Punch-able...
#
#                                           article_only   label   source  \
# 408  WASHINGTON, D.C. (SatireWire.com) – Republican...  satire  Golbeck
# 372                                           Just In:  satire  Golbeck
# 371  WASHINGTON, D.C. (SatireWire.com) – Overlooked...  satire  Golbeck
# 247  Home just eight weeks after being wounded duri...  satire  Golbeck
# 271  CONCORD, NH—Following a strong second place fi...  satire  Golbeck
#
#        unique_id                                               text
# 408  golbeck-297  CANCER ENDORSES REPUBLICAN HEALTHCARE PLAN\nWA...
# 372  golbeck-136  New Comprehensive Investigation Involving Trum...
# 371  golbeck-295  U.S. FISH & WILDLIFE SERIOUSLY CONSIDERING ABU...
# 247  golbeck-470  Iraq War Veteran Dies Trying to Protect Buffet...
# 271  golbeck-129  Ted Cruz Still Leads Polls for Most Punch-able...

# %%
fig = px.bar(golbeck_df['label'].reset_index().groupby('label').count(),
             width=500, height=400)
fig.update_layout(showlegend=False, 
                  title_text='Fake-Satire Class Imbalance', title_x=0.5)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="743b47d6-8589-4dbf-8512-9d05c2974965" class="plotly-graph-div" style="height:400px; width:500px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("743b47d6-8589-4dbf-8512-9d05c2974965")) {                    Plotly.newPlot(                        "743b47d6-8589-4dbf-8512-9d05c2974965",                        [{"alignmentgroup":"True","hovertemplate":"variable=index<br>label=%{x}<br>value=%{y}<extra></extra>","legendgroup":"index","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"index","offsetgroup":"index","orientation":"v","showlegend":true,"textposition":"auto","x":["fake","satire"],"xaxis":"x","y":[230,180],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"line":{"colorbar": ...

# %%
# Mihalcea Real-Fake
mihalcea_df = pd.read_csv(MIHALCEA_PATH, index_col=0)

# Add metadata and standardize
mihalcea_df['source'] = 'Mihalcea'
mihalcea_df['unique_id'] = 'mihalcea-' + mihalcea_df.index.astype(str)
mihalcea_df.rename({'Text': 'text', 'Domain': 'domain', 'Label': 'label'}, 
                   axis=1, inplace=True)
mihalcea_df['label'].replace('legit', 'real', inplace=True)

mihalcea_df.sample(5)
# Out:
#                                                   text     domain label  \
# 559  Chelsea Handler Has Nothing Nice to Say About ...  celebrity  fake
# 10   Ellison: Democrats "gloating" over Republican ...      polit  fake
# 690  Kate Middleton & Prince William Try To Save Cr...  celebrity  fake
# 59   Obama Administration sets new rule for childre...        edu  fake
# 365   What to expect from Carrie Fisher and Debbie ...      entmt  real
#
#        source     unique_id
# 559  Mihalcea  mihalcea-559
# 10   Mihalcea   mihalcea-10
# 690  Mihalcea  mihalcea-690
# 59   Mihalcea   mihalcea-59
# 365  Mihalcea  mihalcea-365

# %%
fig = px.bar(mihalcea_df['label'].reset_index().groupby('label').count(),
             width=500, height=400)
fig.update_layout(showlegend=False, 
                  title_text='Real-Fake Class Imbalance', title_x=0.5)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="854049e9-a092-451b-a0fd-b42ec6434544" class="plotly-graph-div" style="height:400px; width:500px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("854049e9-a092-451b-a0fd-b42ec6434544")) {                    Plotly.newPlot(                        "854049e9-a092-451b-a0fd-b42ec6434544",                        [{"alignmentgroup":"True","hovertemplate":"variable=index<br>label=%{x}<br>value=%{y}<extra></extra>","legendgroup":"index","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"index","offsetgroup":"index","orientation":"v","showlegend":true,"textposition":"auto","x":["fake","real"],"xaxis":"x","y":[490,490],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"line":{"colorbar":{" ...

# %%
# Yang Real-Satire
yang_train_df = pd.read_csv(YANG_TRAIN_PATH)

# Add metadata and standardize
yang_train_df['source'] = 'Yang'
yang_train_df['unique_id'] = 'yang-' + yang_train_df.index.astype(str)
yang_train_df.rename({'content': 'text', 'topic': 'domain'}, 
                     axis=1, inplace=True)
yang_train_df['label'].replace(0, 'satire', inplace=True)
yang_train_df['label'].replace(1, 'real', inplace=True)

yang_train_df.sample(5)
# Out:
#                                                     text label  \
# 31090  as revealed by the mail on sunday , armstrong ...  real
# 18864  the 21 year old has enjoyed a whirlwind few da...  real
# 25465  the announcement was made after a meeting of t...  real
# 30460  actor and politician fred thompson attends the...  real
# 17555  the sukhoi superjet 100 came to rest on the si...  real
#
#                                            clean_content      domain source  \
# 31090  revealed mail sunday  armstrong agreed request...    vacation   Yang
# 18864  21 year old enjoyed whirlwind days since domin...      sports   Yang
# 25465  announcement made meeting atp board directors ...        play   Yang
# 30460  actor politician fred thompson attends opening...    politics   Yang
# 17555  sukhoi superjet 100 came rest side mount salak...  air_travel   Yang
#
#         unique_id
# 31090  yang-31090
# 18864  yang-18864
# 25465  yang-25465
# 30460  yang-30460
# 17555  yang-17555

# %%
fig = px.bar(yang_train_df['label'].reset_index().groupby('label').count(),
             width=500, height=400)
fig.update_layout(showlegend=False, 
                  title_text='Real-Satire Class Imbalance', title_x=0.5)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="3ad1546e-d2e4-4076-a7eb-b7fa0ff1e2a3" class="plotly-graph-div" style="height:400px; width:500px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3ad1546e-d2e4-4076-a7eb-b7fa0ff1e2a3")) {                    Plotly.newPlot(                        "3ad1546e-d2e4-4076-a7eb-b7fa0ff1e2a3",                        [{"alignmentgroup":"True","hovertemplate":"variable=index<br>label=%{x}<br>value=%{y}<extra></extra>","legendgroup":"index","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"index","offsetgroup":"index","orientation":"v","showlegend":true,"textposition":"auto","x":["real","satire"],"xaxis":"x","y":[34706,12613],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"line":{"colorb ...

# %% [markdown]
# ###<b>Concatenate DataFrames</b>

# %%
full_combined_df = pd.concat([golbeck_df, mihalcea_df, yang_train_df], axis=0)
combined_df = full_combined_df[KEEP_COLS]
combined_df.describe()
# Out:
#           unique_id  label source  \
# count         48709  48709  48709
# unique        48709      3      3
# top     golbeck-316   real   Yang
# freq              1  35196  47319
#
#                                                      text
# count                                               48708
# unique                                              48622
# top     an excess of government buildings and restrict...
# freq                                                    2

# %%
# Final check for duplicates (in 'text')
num_dups = combined_df.duplicated('text').sum()

combined_df['text'] = combined_df['text'].astype(str)
print(f'There are {num_dups} duplicates.')
combined_df = combined_df[~combined_df.duplicated('text')]
print('Records with duplicate text have been removed')

# Check for NaN
combined_df = combined_df.dropna()
# Out:
# <ipython-input-12-2660f30ded28>:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# There are 86 duplicates.
# Records with duplicate text have been removed

# %%
combined_df.sample(5)
# Out:
#           unique_id   label    source  \
# 11216    yang-11216    real      Yang
# 919        yang-919    real      Yang
# 142    mihalcea-142    fake  Mihalcea
# 36309    yang-36309    real      Yang
# 38485    yang-38485  satire      Yang
#
#                                                     text
# 11216  lira is worst performer in emerging markets , ...
# 919    chris megerian and noam n . levey contact repo...
# 142    Google computers defeat shows once again nothi...
# 36309  serena had to save set points in her second ro...
# 38485  thurmond , 93 , first elected to congress in 1...

# %% [markdown]
# ###<b>Clean Text & Remove Stop Words</b>

# %%
def remove_stop_punct(df, col_name, updated_col_name, re):
    """
    Removes stop words and punctuations from the dataframe

    Parameters
    ----------
    df : pandas dataframe
        The dataframe to remove stop words and punctuations from
    col_name : str
        The name of the column to remove stop words and punctuations from
    updated_col_name : str
        The name of the column to store the updated content
    re : str
        Regex
    """
    print("Removing stop words and punctuations...")
    df[updated_col_name] = df[col_name].apply(lambda x: ' '.join([word for word in x.split() if word not in (STOPS)]))
    df[updated_col_name] = df[updated_col_name].str.replace(re,'')
    print("Stop words and punctuations are removed successfully!")
    return df

# %%
clean_combined_df = remove_stop_punct(combined_df, 
                                      col_name='text', 
                                      updated_col_name='clean_text', 
                                      re='[^\w\s]'
                                      )
# Out:
# Removing stop words and punctuations...
# <ipython-input-14-4561fc6db9e3>:18: FutureWarning:
#
# The default value of regex will change from True to False in a future version.
# Stop words and punctuations are removed successfully!

# %% [markdown]
# ###<b>Save to CSV for Modeling</b>

# %%
clean_combined_df.dropna().to_csv(COMBINED_PATH, index=False)

# %% [markdown]
# ###<b>Review Combined Dataset</b>

# %%
fig = px.bar(clean_combined_df['label'].reset_index().groupby('label').count(),
             width=500, height=400)
fig.update_layout(showlegend=False, 
                  title_text='Real-Fake-Satire Class Imbalance', title_x=0.5)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="2d96a47b-96d1-40d0-b8cc-a8a145c8fd47" class="plotly-graph-div" style="height:400px; width:500px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2d96a47b-96d1-40d0-b8cc-a8a145c8fd47")) {                    Plotly.newPlot(                        "2d96a47b-96d1-40d0-b8cc-a8a145c8fd47",                        [{"alignmentgroup":"True","hovertemplate":"variable=index<br>label=%{x}<br>value=%{y}<extra></extra>","legendgroup":"index","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"index","offsetgroup":"index","orientation":"v","showlegend":true,"textposition":"auto","x":["fake","real","satire"],"xaxis":"x","y":[720,35110,12793],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"lin ...

# %%
clean_combined_df.sample(5)
# Out:
#         unique_id label source  \
# 20904  yang-20904  real   Yang
# 10748  yang-10748  real   Yang
# 32997  yang-32997  real   Yang
# 36386  yang-36386  real   Yang
# 3760    yang-3760  real   Yang
#
#                                                     text  \
# 20904  but presidential nominations are not won purel...
# 10748  it is understood the prime minister will say s...
# 32997  in the light and spirit ( of holocaust memoria...
# 36386  the dead spotted eagle ray lies on the deck of...
# 3760   alice barker snapped her fingers and sang alon...
#
#                                               clean_text
# 20904  presidential nominations purely national polls...
# 10748  understood prime minister say sorry weekly aud...
# 32997  light spirit  holocaust memorial day  speaker ...
# 36386  dead spotted eagle ray lies deck boat florida ...
# 3760   alice barker snapped fingers sang along videos...
